# %%
#necessary libraries
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("Health Monitor Dataset.xlsx")
df
# Out:
#       Dehydration  Medicine Overdose  Acidious  Cold   Cough  Dehydration.1  \
# 0            True              False     False  False  False              1
# 1           False              False      True  False   True              0
# 2           False               True      True  False   True              0
# 3            True              False     False  False  False              1
# 4            True               True      True  False   True              1
# ...           ...                ...       ...    ...    ...            ...
# 4281        False               True      True  False  False              0
# 4282        False              False     False  False  False              0
# 4283         True               True      True  False  False              1
# 4284         True              False      True   True   True              1
# 4285         True               True      True   True   True              1
#
# ...

# %%
df.head()
# Out:
#    Dehydration  Medicine Overdose  Acidious  Cold   Cough  Dehydration.1  \
# 0         True              False     False  False  False              1
# 1        False              False      True  False   True              0
# 2        False               True      True  False   True              0
# 3         True              False     False  False  False              1
# 4         True               True      True  False   True              1
#
#    Medicine Overdose.1  Acidious.1  Cold .1  Cough.1  Type  Temperature  \
# 0                    0           0        0        0     1           98
# 1                    0           1        0        1     2           98
# 2                    1           1        0        1     3          103
# 3                    0           0        0        0     1           98
# 4                    1           1        0        1     4          105
#
#    Heart Rate  Pulse  BPSYS  BPDIA  Respiratory Rate  Oxygen Saturation  PH  \
# ...

# %%
df.dtypes
# Out:
# Dehydration                        bool
# Medicine Overdose                  bool
# Acidious                           bool
# Cold                               bool
# Cough                              bool
# Dehydration.1                     int64
# Medicine Overdose.1               int64
# Acidious.1                        int64
# Cold .1                           int64
# Cough.1                           int64
# Type                              int64
# Temperature                       int64
# Heart Rate                        int64
# Pulse                             int64
# BPSYS                             int64
# BPDIA                             int64
# Respiratory Rate                  int64
# Oxygen Saturation               float64
# PH                                int64
# Causes Respiratory Imbalance     object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4286 entries, 0 to 4285
# Data columns (total 20 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Dehydration                   4286 non-null   bool
#  1   Medicine Overdose             4286 non-null   bool
#  2   Acidious                      4286 non-null   bool
#  3   Cold                          4286 non-null   bool
#  4   Cough                         4286 non-null   bool
#  5   Dehydration.1                 4286 non-null   int64
#  6   Medicine Overdose.1           4286 non-null   int64
#  7   Acidious.1                    4286 non-null   int64
#  8   Cold .1                       4286 non-null   int64
#  9   Cough.1                       4286 non-null   int64
#  10  Type                          4286 non-null   int64
#  11  Temperature                   4286 non-null   int64
#  12  Heart Rate                    4286 non-null   int64
# ...

# %%
df.shape
# Out:
# (4286, 20)

# %%
#analytical summary of the dataset
df.describe(include='all')
# Out:
#        Dehydration Medicine Overdose Acidious  Cold  Cough  Dehydration.1  \
# count         4286              4286     4286   4286  4286    4286.000000
# unique           2                 2        2      2     2            NaN
# top          False              True    False  False  True            NaN
# freq          2189              2144     2178   2234  2155            NaN
# mean           NaN               NaN      NaN    NaN   NaN       0.489267
# std            NaN               NaN      NaN    NaN   NaN       0.499943
# min            NaN               NaN      NaN    NaN   NaN       0.000000
# 25%            NaN               NaN      NaN    NaN   NaN       0.000000
# 50%            NaN               NaN      NaN    NaN   NaN       0.000000
# 75%            NaN               NaN      NaN    NaN   NaN       1.000000
# max            NaN               NaN      NaN    NaN   NaN       1.000000
#
#         Medicine Overdose.1   Acidious.1      Cold .1     Cough.1  \
# ...

# %%
df.columns
# Out:
# Index(['Dehydration', 'Medicine Overdose', 'Acidious', 'Cold ', 'Cough',
#        'Dehydration.1', 'Medicine Overdose.1', 'Acidious.1', 'Cold .1',
#        'Cough.1', 'Type', 'Temperature', 'Heart Rate', 'Pulse', 'BPSYS',
#        'BPDIA', 'Respiratory Rate', 'Oxygen Saturation', 'PH',
#        'Causes Respiratory Imbalance'],
#       dtype='object')

# %%
#checking for missing values
df.isnull().sum()
# Out:
# Dehydration                     0
# Medicine Overdose               0
# Acidious                        0
# Cold                            0
# Cough                           0
# Dehydration.1                   0
# Medicine Overdose.1             0
# Acidious.1                      0
# Cold .1                         0
# Cough.1                         0
# Type                            0
# Temperature                     0
# Heart Rate                      0
# Pulse                           0
# BPSYS                           0
# BPDIA                           0
# Respiratory Rate                0
# Oxygen Saturation               0
# PH                              0
# Causes Respiratory Imbalance    0
# dtype: int64

# %%
df.describe(include='object')
# Out:
#        Causes Respiratory Imbalance
# count                          4286
# unique                            4
# top                         Chronic
# freq                           2085

# %%
df.describe(include = 'bool')
# Out:
#        Dehydration Medicine Overdose Acidious  Cold  Cough
# count         4286              4286     4286   4286  4286
# unique           2                 2        2      2     2
# top          False              True    False  False  True
# freq          2189              2144     2178   2234  2155

# %%
df.describe(include = 'int64')
# Out:
#        Dehydration.1  Medicine Overdose.1   Acidious.1      Cold .1  \
# count    4286.000000          4286.000000  4286.000000  4286.000000
# mean        0.489267             0.500233     0.491834     0.478768
# std         0.499943             0.500058     0.499992     0.499607
# min         0.000000             0.000000     0.000000     0.000000
# 25%         0.000000             0.000000     0.000000     0.000000
# 50%         0.000000             1.000000     0.000000     0.000000
# 75%         1.000000             1.000000     1.000000     1.000000
# max         1.000000             1.000000     1.000000     1.000000
#
#           Cough.1         Type  Temperature   Heart Rate        Pulse  \
# count  4286.00000  4286.000000  4286.000000  4286.000000  4286.000000
# mean      0.50280     2.462902   100.167989   115.208586   113.360243
# std       0.50005     1.120677     3.203449    43.326482    46.123845
# min       0.00000     0.000000    95.000000    50.000000    50.000000
# ...

# %%
df['Causes Respiratory Imbalance'].value_counts()
# Out:
# Chronic    2085
# Severe     1362
# Mild        689
# Normal      150
# Name: Causes Respiratory Imbalance, dtype: int64

# %%
df.head()
# Out:
#    Dehydration  Medicine Overdose  Acidious  Cold   Cough  Dehydration.1  \
# 0         True              False     False  False  False              1
# 1        False              False      True  False   True              0
# 2        False               True      True  False   True              0
# 3         True              False     False  False  False              1
# 4         True               True      True  False   True              1
#
#    Medicine Overdose.1  Acidious.1  Cold .1  Cough.1  Type  Temperature  \
# 0                    0           0        0        0     1           98
# 1                    0           1        0        1     2           98
# 2                    1           1        0        1     3          103
# 3                    0           0        0        0     1           98
# 4                    1           1        0        1     4          105
#
#    Heart Rate  Pulse  BPSYS  BPDIA  Respiratory Rate  Oxygen Saturation  PH  \
# ...

# %%
#dropping unecessary columns
df2 = df.drop(['Dehydration.1','Medicine Overdose.1','Acidious.1','Cold .1','Cough.1'],axis=1)

# %%
df2
# Out:
#       Dehydration  Medicine Overdose  Acidious  Cold   Cough  Type  \
# 0            True              False     False  False  False     1
# 1           False              False      True  False   True     2
# 2           False               True      True  False   True     3
# 3            True              False     False  False  False     1
# 4            True               True      True  False   True     4
# ...           ...                ...       ...    ...    ...   ...
# 4281        False               True      True  False  False     2
# 4282        False              False     False  False  False     0
# 4283         True               True      True  False  False     3
# 4284         True              False      True   True   True     4
# 4285         True               True      True   True   True     5
#
#       Temperature  Heart Rate  Pulse  BPSYS  BPDIA  Respiratory Rate  \
# 0              98          93     67     90     74                12
# ...

# %%
df2.shape
# Out:
# (4286, 15)

# %%
df2.nunique()
# Out:
# Dehydration                        2
# Medicine Overdose                  2
# Acidious                           2
# Cold                               2
# Cough                              2
# Type                               6
# Temperature                       12
# Heart Rate                       151
# Pulse                            151
# BPSYS                             31
# BPDIA                             61
# Respiratory Rate                  55
# Oxygen Saturation               4286
# PH                                14
# Causes Respiratory Imbalance       4
# dtype: int64

# %%
df2['Causes Respiratory Imbalance'].unique()
# Out:
# array(['Mild', 'Severe', 'Chronic', 'Normal'], dtype=object)

# %%
df2.corr()
# Out:
#                    Dehydration  Medicine Overdose  Acidious     Cold   \
# Dehydration           1.000000          -0.009325 -0.004085  0.016840
# Medicine Overdose    -0.009325           1.000000  0.017275  0.009828
# Acidious             -0.004085           0.017275  1.000000  0.009115
# Cold                  0.016840           0.009828  0.009115  1.000000
# Cough                -0.025551          -0.001869 -0.016710  0.017052
# Type                  0.436231           0.453306  0.448645  0.469382
# Temperature           0.070925           0.070049  0.059866  0.087385
# Heart Rate            0.125167           0.147685  0.132779  0.119800
# Pulse                 0.143090           0.159540  0.163761  0.184133
# BPSYS                -0.098361          -0.105834 -0.125043 -0.122332
# BPDIA                -0.016804           0.017565  0.002796 -0.004896
# Respiratory Rate      0.136612           0.149683  0.125398  0.155721
# ...

# %%
#sb.pairplot(df2)

# %%
df2.head()
# Out:
#    Dehydration  Medicine Overdose  Acidious  Cold   Cough  Type  Temperature  \
# 0         True              False     False  False  False     1           98
# 1        False              False      True  False   True     2           98
# 2        False               True      True  False   True     3          103
# 3         True              False     False  False  False     1           98
# 4         True               True      True  False   True     4          105
#
#    Heart Rate  Pulse  BPSYS  BPDIA  Respiratory Rate  Oxygen Saturation  PH  \
# 0          93     67     90     74                12           0.994164   8
# 1         185    160    100     74                47           0.913976  13
# 2         126    194     97     47                42           0.932465  10
# 3          92     69     91     60                16           0.999605   8
# 4         197    115    106     87                39           0.971081  13
#
#   Causes Respiratory Imbalance
# ...

# %% [markdown]
# ### Univariate

# %%
sb.displot(df2['Heart Rate'])

# %%
df2['Temperature'].mean()
# Out:
# 100.16798880074661

# %%
df2['PH'].median()
# Out:
# 8.0

# %%
df2['Type'].mode()
# Out:
# 0    2
# dtype: int64

# %%
sb.countplot(df2['Causes Respiratory Imbalance'],data=df2)
# Out:
# /home/student/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Causes Respiratory Imbalance', ylabel='count'>

# %%
sb.countplot(df2['Type'])
# Out:
# /home/student/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Type', ylabel='count'>

# %%
sb.catplot(x='Type',kind='box',data=df2)

# %%
sb.histplot(df2['Oxygen Saturation'])
# Out:
# <AxesSubplot:xlabel='Oxygen Saturation', ylabel='Count'>

# %%
x = df2['Causes Respiratory Imbalance'].value_counts()
plt.pie(x.values,labels=x.index,autopct='%1.1f%%')
plt.show()

# %%
x2 = df2['Type'].value_counts()
plt.pie(x2.values,labels=x2.index,autopct='%1.1f%%')
plt.show()

# %%
sb.set(rc={'figure.figsize':(6,6)})
sb.kdeplot(df2['Heart Rate'],shade='True')
# Out:
# <AxesSubplot:xlabel='Heart Rate', ylabel='Density'>

# %%
plt.figure(figsize=(5,5))
plt.violinplot(df2['Type'],showmedians=True)
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x7fedf920dfd0>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x7fedf920dd90>,
#  'cmins': <matplotlib.collections.LineCollection at 0x7fedf921c520>,
#  'cbars': <matplotlib.collections.LineCollection at 0x7fedf921c850>,
#  'cmedians': <matplotlib.collections.LineCollection at 0x7fedf921cb80>}

# %% [markdown]
# # Bivariate Analysis

# %% [markdown]
# Bivariate analysis is the simultaneous analysis of two variables. It explores the concept of the relationship between two variable whether there exists an association and the strength of this association or whether there are differences between two variables and the significance of these differences.
#
# The main three types we will see here are:
#
# ->Categorical v/s Numerical
#
# ->Numerical V/s Numerical
#
# ->Categorical V/s Categorical data

# %%
plt.figure(figsize=(15,5))
sb.barplot(x=df2['Causes Respiratory Imbalance'],y=df2['Heart Rate'])
plt.show()

# %% [markdown]
# Numerical VS Numerical

# %%
sb.scatterplot(x=df2['Heart Rate'],y=df2['Respiratory Rate'])
# Out:
# <AxesSubplot:xlabel='Heart Rate', ylabel='Respiratory Rate'>

# %%
sb.stripplot(x=df2['Causes Respiratory Imbalance'],y=df2['Type'])
# Out:
# <AxesSubplot:xlabel='Causes Respiratory Imbalance', ylabel='Type'>

# %%
sb.scatterplot(x=df2['Type'],y=df2['Temperature'])
# Out:
# <AxesSubplot:xlabel='Type', ylabel='Temperature'>

# %%
sb.jointplot(x=df2['Temperature'],y=df2['Respiratory Rate'],hue='Causes Respiratory Imbalance',palette='bright',data=df2)
plt.show()

# %%
sb.jointplot(data = df2, x = 'Type', y = 'Oxygen Saturation');
plt.show()

# %%
sb.jointplot(data = df2, x = 'Type', y = 'BPDIA',kind='reg')
plt.show()

# %%
sb.scatterplot(x=df2.index,y=df2['Pulse'],hue = df2['Causes Respiratory Imbalance'])
# Out:
# <AxesSubplot:ylabel='Pulse'>

# %% [markdown]
# # MULTIVARIATE:

# %%
def graph(y):
    sb.boxplot(x="charges", y=y, data=df2)
plt.figure(figsize=(10,10))
c=0;
for i in df2.columns[0:5]:
    plt.subplot(521+c)
    c+=1
    graph(i)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 3
#       1 def graph(y):
#       2     sb.boxplot(x="charges", y=y, data=df2)
# ----> 3 plt.figure(figsize=(10,10))
#       4 c=0;
#       5 for i in df2.columns[0:5]:
#
# NameError: name 'plt' is not defined

# %%
df3=df2.drop(['Dehydration','Medicine Overdose','Acidious','Cold ','Cough'],axis=1)

# %%
sb.pairplot(df3)

# %%
correlation = df2.corr()
fig, ax = plt.subplots(figsize=(20,20)) 
sb.heatmap(correlation, xticklabels = correlation.columns, yticklabels = correlation.columns,cmap="YlGnBu",annot= True)
# Out:
# <AxesSubplot:>

# %%
sb.relplot(x='Temperature',y='Respiratory Rate',hue='Causes Respiratory Imbalance',data=df2)

# %%
plt.figure(figsize=(25,5))
sb.violinplot(x=df['Cold .1'],y=df2['Oxygen Saturation'],hue='Causes Respiratory Imbalance',data=df2)
# Out:
# <AxesSubplot:xlabel='Cold .1', ylabel='Oxygen Saturation'>

# %%
sb.barplot(x=df2['Causes Respiratory Imbalance'],y=df2['Temperature'],hue='Causes Respiratory Imbalance',data=df2)
# Out:
# <AxesSubplot:xlabel='Causes Respiratory Imbalance', ylabel='Temperature'>

# %%
sb.relplot(data=df2,x=df2['BPSYS'],y=df2['BPDIA'],hue='Causes Respiratory Imbalance',col='Type',kind='scatter')

# %%
#high temeperature means higher respiratory rate->running or fever
sb.relplot(data=df2,x=df2['Temperature'],y=df2['Respiratory Rate'],hue=df2['Causes Respiratory Imbalance'],kind='line')

# %% [markdown]
# # Naive Bayesian Classifier

# %%
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import balanced_accuracy_score

# %%
df2.columns
# Out:
# Index(['Dehydration', 'Medicine Overdose', 'Acidious', 'Cold ', 'Cough',
#        'Type', 'Temperature', 'Heart Rate', 'Pulse', 'BPSYS', 'BPDIA',
#        'Respiratory Rate', 'Oxygen Saturation', 'PH',
#        'Causes Respiratory Imbalance'],
#       dtype='object')

# %%
X=df2.drop('Causes Respiratory Imbalance',axis=1)
y=df2['Causes Respiratory Imbalance']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
gnb = GaussianNB()
y_pred = gnb.fit(X_train, y_train).predict(X_test)

# %%
balanced_accuracy_score(y_test, y_pred)
# Out:
# 1.0

# %% [markdown]
# # SVM

# %%
import numpy
from sklearn import preprocessing

label_encoder = preprocessing.LabelEncoder()
for i in df2.columns:
    if type(df2[i][2])==numpy.bool_ or type(df2[i][0])==str:
        df2[i]= label_encoder.fit_transform(df2[i])

# %% [markdown]
# ## Classification

# %%
X=df2.drop('Causes Respiratory Imbalance',axis=1)
y=df2['Causes Respiratory Imbalance']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=0)

# %%
from sklearn import svm

clf = svm.SVC()
y_pred=clf.fit(X, y).predict(X_test)

# %%
balanced_accuracy_score(y_test, y_pred)
# Out:
# 0.487007874015748

# %% [markdown]
# ## Regression

# %%
X=df2.drop('Pulse',axis=1)
y=df2['Pulse']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
from sklearn import svm
clf = svm.SVR()
y_pred=clf.fit(X, y).predict(X_test)

# %%
import sklearn.metrics as sm
import math
x=math.sqrt(sm.mean_squared_error(y_test, y_pred))
x
# Out:
# 46.04600290260631

# %%
#normalised root mean squared error
x/(df.Pulse.min()+df.Pulse.max())
# Out:
# 0.18418401161042525

# %% [markdown]
# # Multiple Regression

# %%
from sklearn.linear_model import LinearRegression
X=df2.drop('Pulse',axis=1)
y=df2['Pulse']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
model = LinearRegression()
model.fit(X_train, y_train)
y_pred=model.predict(X_test)
x=math.sqrt(sm.mean_squared_error(y_test, y_pred))

# %%
x
# Out:
# 40.85260820358596

# %%
#Normalised root mean squared error
x/(df.Pulse.min()+df.Pulse.max())
# Out:
# 0.16341043281434384

# %%
import numpy as np
import matplotlib.pyplot as plt

def estimate_coef(x, y):
    # number of observations/points
    n = np.size(x)

    # mean of x and y vector
    m_x = np.mean(x)
    m_y = np.mean(y)

    # calculating cross-deviation and deviation about x
    SS_xy = np.sum(y*x) - n*m_y*m_x
    SS_xx = np.sum(x*x) - n*m_x*m_x

    # calculating regression coefficients
    b_1 = SS_xy / SS_xx
    b_0 = m_y - b_1*m_x

    return (b_0, b_1)

def plot_regression_line(x, y, b):
    # plotting the actual points as scatter plot
    plt.scatter(x, y, color = "m",marker = "o", s = 30)

    # predicted response vector
    y_pred = b[0] + b[1]*x

    # plotting the regression line
    plt.plot(x, y_pred, color = "g")

    # putting labels
    plt.xlabel('x')
    plt.ylabel('y')

    # function to show plot
    plt.show()

def main():
    # observations / data
    x=df2["Heart Rate"]
    y=df2['Pulse']

    # estimating coefficients
    b = estimate_coef(x, y)
    print("Estimated coefficients:\nb_0 = {} \nb_1 = {}".format(b[0], b[1]))

    # plotting regression line
    plot_regression_line(x, y, b)

if __name__ == "__main__":
    main()
# Out:
# Estimated coefficients:
# b_0 = 90.65984807204332
# b_1 = 0.1970373506699738

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
X=df2.drop('Causes Respiratory Imbalance',axis=1)
y=df2['Causes Respiratory Imbalance']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
model = LogisticRegression(random_state=0,max_iter=10000)
model.fit(X_train, y_train)
y_pred=model.predict(X_test)

# %%
balanced_accuracy_score(y_test, y_pred)
# Out:
# 0.9987864077669903
